# %% [markdown]
# # Indiana High School Graduation Rates Study

# %% [markdown]
# This study digs into the graduation rates in Indiana high schools by separating out those students who received diplomas verses those who received waivers. We'll examine the relationships between diploma rates and federal school grade; diploma rates and school size; diploma rates and school attendance; and any trends and outliers that appear in the data.

# %%
#Dependencies
import pandas as pd

# %%
# Save file path to Excel files (only looking at school demographics to begin) 
school_demo2015 = pd.read_csv('Resources/School_Demographics2015.csv')
school_demo2016 = pd.read_csv('Resources/School_Demographics2016.csv')
school_demo2017 = pd.read_csv('Resources/School_Demographics2017.csv')
school_demo2018 = pd.read_csv('Resources/School_Demographics2018.csv')
school_demo2019 = pd.read_csv('Resources/School_Demographics2019.csv')
#school_demo2018.head()

# %%
# read column names. csv file used two rows to id columns. Pandas will use one row as column names.
school_demo2015.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'American Indian', 'Unnamed: 3',
#        'Unnamed: 4', 'Asian', 'Unnamed: 6', 'Unnamed: 7', 'Black',
#        'Unnamed: 9', 'Unnamed: 10', 'Hispanic', 'Unnamed: 12', 'Unnamed: 13',
#        'Multiracial', 'Unnamed: 15', 'Unnamed: 16',
#        'Native Hawaiian or Other Pacific Islander', 'Unnamed: 18',
#        'Unnamed: 19', 'White', 'Unnamed: 21', 'Unnamed: 22', 'Paid meals',
#        'Unnamed: 24', 'Unnamed: 25', 'Free/Reduced price meals', 'Unnamed: 27',
#        'Unnamed: 28', 'General Education', 'Unnamed: 30', 'Unnamed: 31',
#        'Special Education', 'Unnamed: 33', 'Unnamed: 34',
#        'Non-English Language Learner', 'Unnamed: 36', 'Unnamed: 37',
#        'English Language Learner', 'Unnamed: 39', 'Unnamed: 40', 'Female',
#        'Unnamed: 42', 'Unnamed: 43', 'Male', 'Unnamed: 45', 'Unnamed: 46',
#        'Total', 'Unnamed: 48', 'Unnamed: 49'],
#       dtype='object')

# %%
# rename columns for df use in pandas
renamed2015 = school_demo2015.rename(columns={"Unnamed: 0":"Corp ID", 
                                            "Unnamed: 1":"Corporation Name",
                                            "American Indian":"Native American Cohort Count",
                                            "Unnamed: 3":"Native American Graduates",
                                            "Unnamed: 4":"Native American Grad Rate",
                                            "Asian":"Asian Cohort Count",
                                            "Unnamed: 6":"Asian Graduates",
                                            "Unnamed: 7":"Asian Grad Rate",
                                            "Black":"Black Cohort Count",
                                            "Unnamed: 9":"Black Graduates",
                                            "Unnamed: 10":"Black Grad Rate",
                                            "Hispanic":"Hispanic Cohort Count",
                                            "Unnamed: 12":"Hispanic Graduates",
                                            "Unnamed: 13":"Hispanic Grad Rate",
                                            "Multiracial":"Multiracial Cohort Count",
                                            "Unnamed: 15":"Multiracial Graduates",
                                            "Unnamed: 16":"Multiracial Grad Rate",
                                            "Native Hawaiian or Other Pacific Islander":"Native Pacific Islander Cohort Count",
                                            "Unnamed: 18":"Native Pacific Islander Graduates",
                                            "Unnamed: 19":"Native Pacific Islander Grad Rate",
                                            "White":"White Cohort Count", 
                                            "Unnamed: 21":"White Graduates",
                                            "Unnamed: 22":"White Grad Rate",
                                            "Paid Meals":"Paid Meals Cohort Count",
                                            "Unnamed: 24":"Paid Meals Graduates", 
                                            "Unnamed: 25":"Paid Meals Grad Rate",
                                            "Free/Reduced Price Meals":"Free/Reduced Meals Cohort Count",
                                            "Unnamed: 27":"Free/Reduced Meals Graduates",
                                            "Unnamed: 28":"Free/Reduced Meals Grad Rate",
                                            "General Education":"General Ed Cohort Count",
                                            "Unnamed: 30":"General Ed Graduates",
                                            "Unnamed: 31":"General Ed Grad Rate",
                                            "Special Education":"Special Ed Cohort Count",
                                            "Unnamed: 33":"Special Ed Graduates",
                                            "Unnamed: 34":"Special Ed Grad Rate",
                                            "Non-English Language Learner":"Non-English Language Learner Cohort Count", 
                                            "Unnamed: 36":"Non-English Language Learner Graduates",
                                            "Unnamed: 37":"Non-English Language Learner Grad Rate",
                                            "English Language Learner":"English Language Learner Cohort Count",
                                            "Unnamed: 39":"English Language Learner Graduates",
                                            "Unnamed: 40":"English Language Learner Grad Rate",
                                            "Female":"Female Cohort Count",
                                            "Unnamed: 42":"Female Graduates",
                                            "Unnamed: 43":"Female Grad Rate",
                                            "Male":"Male Cohort Count",
                                            "Unnamed: 45":"Male Graduates", 
                                            "Unnamed: 46":"Male Grad Rate",
                                            "Total":"Total Cohort Count", 
                                            "Unnamed: 48":"Total Graduates", 
                                            "Unnamed: 49":"Total Grad Rate"})
#renamed2015.head()

# %%
# drop the first row of data that csv file used as second column id row
clean_demo2015 = renamed2015.drop([0])
clean_demo2015.head()
# Out:
#   Corp ID                    Corporation Name Native American Cohort Count  \
# 1    0015     Adams Central Community Schools                          ***
# 2    0025       North Adams Community Schools                          NaN
# 3    0035                 South Adams Schools                          NaN
# 4    0125  M S D Southwest Allen County Schls                          NaN
# 5    0225      Northwest Allen County Schools                          ***
#
#   Native American Graduates Native American Grad Rate Asian Cohort Count  \
# 1                       ***                       ***                ***
# 2                       NaN                       NaN                ***
# 3                       NaN                       NaN                ***
# 4                       NaN                       NaN                 26
# 5                       ***                       ***                 12
#
# ...

# %%
school_demo2016.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'American Indian', 'American Indian.1',
#        'American Indian.2', 'Asian', 'Asian.1', 'Asian.2', 'Black', 'Black.1',
#        'Black.2', 'Hispanic', 'Hispanic.1', 'Hispanic.2', 'Multiracial',
#        'Multiracial.1', 'Multiracial.2',
#        'Native Hawaiian or Other Pacific Islander',
#        'Native Hawaiian or Other Pacific Islander.1',
#        'Native Hawaiian or Other Pacific Islander.2', 'White', 'White.1',
#        'White.2', 'Paid meals', 'Paid meals.1', 'Paid meals.2',
#        'Free/Reduced price meals', 'Free/Reduced price meals.1',
#        'Free/Reduced price meals.2', 'General Education',
#        'General Education.1', 'General Education.2', 'Special Education',
#        'Special Education.1', 'Special Education.2',
#        'Non-English Language Learner', 'Non-English Language Learner.1',
#        'Non-English Language Learner.2', 'English Language Learner',
# ...

# %%
# rename columns for df use in pandas
renamed2016 = school_demo2016.rename(columns={"Unnamed: 0":"Corp ID", 
                                            "Unnamed: 1":"Corporation Name",
                                            "American Indian":"Native American Cohort Count",
                                            "American Indian.1":"Native American Graduates",
                                            "American Indian.2":"Native American Grad Rate",
                                            "Asian":"Asian Cohort Count",
                                            "Asian.1":"Asian Graduates",
                                            "Asian.2":"Asian Grad Rate",
                                            "Black":"Black Cohort Count",
                                            "Black.1":"Black Graduates",
                                            "Black.2":"Black Grad Rate",
                                            "Hispanic":"Hispanic Cohort Count",
                                            "Hispanic.1":"Hispanic Graduates",
                                            "Hispanic.2":"Hispanic Grad Rate",
                                            "Multiracial":"Multiracial Cohort Count",
                                            "Multiracial.1":"Multiracial Graduates",
                                            "Multiracial.2":"Multiracial Grad Rate",
                                            "Native Hawaiian or Other Pacific Islander":"Native Pacific Islander Cohort Count",
                                            "Native Hawaiian or Other Pacific Islander.1":"Native Pacific Islander Graduates",
                                            "Native Hawaiian or Other Pacific Islander.2":"Native Pacific Islander Grad Rate",
                                            "White":"White Cohort Count", 
                                            "White.1":"White Graduates",
                                            "White.2":"White Grad Rate",
                                            "Paid Meals":"Paid Meals Cohort Count",
                                            "Paid Meals.1":"Paid Meals Graduates", 
                                            "Paid Meals.2":"Paid Meals Grad Rate",
                                            "Free/Reduced Price Meals":"Free/Reduced Meals Cohort Count",
                                            "Free/Reduced Price Meals.1":"Free/Reduced Meals Graduates",
                                            "Free/Reduced Price Meals.2":"Free/Reduced Meals Grad Rate",
                                            "General Education":"General Ed Cohort Count",
                                            "General Education.1":"General Ed Graduates",
                                            "General Education.2":"General Ed Grad Rate",
                                            "Special Education":"Special Ed Cohort Count",
                                            "Special Education.1":"Special Ed Graduates",
                                            "Special Education.2":"Special Ed Grad Rate",
                                            "Non-English Language Learner":"Non-English Language Learner Cohort Count", 
                                            "Non-English Language Learner.1":"Non-English Language Learner Graduates",
                                            "Non-English Language Learner.2":"Non-English Language Learner Grad Rate",
                                            "English Language Learner":"English Language Learner Cohort Count",
                                            "English Language Learner.1":"English Language Learner Graduates",
                                            "English Language Learner.2":"English Language Learner Grad Rate",
                                            "Female":"Female Cohort Count",
                                            "Female.1":"Female Graduates",
                                            "Female.2":"Female Grad Rate",
                                            "Male":"Male Cohort Count",
                                            "Male.1":"Male Graduates", 
                                            "Male.2":"Male Grad Rate",
                                            "Total":"Total Cohort Count", 
                                            "Unnamed: 48":"Total Graduates", 
                                            "Unnamed: 49":"Total Grad Rate"})
#renamed2016.head()

# %%
clean_demo2016 = renamed2016.drop([0])
clean_demo2016.head()
# Out:
#   Corp ID                    Corporation Name Native American Cohort Count  \
# 1    0015     Adams Central Community Schools                          NaN
# 2    0025       North Adams Community Schools                          ***
# 3    0035                 South Adams Schools                          NaN
# 4    0125  M S D Southwest Allen County Schls                          ***
# 5    0225      Northwest Allen County Schools                          NaN
#
#   Native American Graduates Native American Grad Rate Asian Cohort Count  \
# 1                       NaN                       NaN                NaN
# 2                       ***                       ***                NaN
# 3                       NaN                       NaN                NaN
# 4                       ***                       ***                 23
# 5                       NaN                       NaN                 19
#
# ...

# %%
school_demo2017.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'American Indian', 'Unnamed: 3',
#        'Unnamed: 4', 'Asian', 'Unnamed: 6', 'Unnamed: 7', 'Black',
#        'Unnamed: 9', 'Unnamed: 10', 'Hispanic', 'Unnamed: 12', 'Unnamed: 13',
#        'Multiracial', 'Unnamed: 15', 'Unnamed: 16',
#        'Native Hawaiian or Other Pacific Islander', 'Unnamed: 18',
#        'Unnamed: 19', 'White', 'Unnamed: 21', 'Unnamed: 22', 'Paid Meals',
#        'Unnamed: 24', 'Unnamed: 25', 'Free/Reduced Price Meals', 'Unnamed: 27',
#        'Unnamed: 28', 'General Education', 'Unnamed: 30', 'Unnamed: 31',
#        'Special Education', 'Unnamed: 33', 'Unnamed: 34',
#        'Non-English Language Learner', 'Unnamed: 36', 'Unnamed: 37',
#        'English Language Learner', 'Unnamed: 39', 'Unnamed: 40', 'Female',
#        'Unnamed: 42', 'Unnamed: 43', 'Male', 'Unnamed: 45', 'Unnamed: 46',
#        'Total', 'Unnamed: 48', 'Unnamed: 49'],
#       dtype='object')

# %%
# rename columns for df use in pandas
renamed2017 = school_demo2017.rename(columns={"Unnamed: 0":"Corp ID", 
                                            "Unnamed: 1":"Corporation Name",
                                            "American Indian":"Native American Cohort Count",
                                            "Unnamed: 3":"Native American Graduates",
                                            "Unnamed: 4":"Native American Grad Rate",
                                            "Asian":"Asian Cohort Count",
                                            "Unnamed: 6":"Asian Graduates",
                                            "Unnamed: 7":"Asian Grad Rate",
                                            "Black":"Black Cohort Count",
                                            "Unnamed: 9":"Black Graduates",
                                            "Unnamed: 10":"Black Grad Rate",
                                            "Hispanic":"Hispanic Cohort Count",
                                            "Unnamed: 12":"Hispanic Graduates",
                                            "Unnamed: 13":"Hispanic Grad Rate",
                                            "Multiracial":"Multiracial Cohort Count",
                                            "Unnamed: 15":"Multiracial Graduates",
                                            "Unnamed: 16":"Multiracial Grad Rate",
                                            "Native Hawaiian or Other Pacific Islander":"Native Pacific Islander Cohort Count",
                                            "Unnamed: 18":"Native Pacific Islander Graduates",
                                            "Unnamed: 19":"Native Pacific Islander Grad Rate",
                                            "White":"White Cohort Count", 
                                            "Unnamed: 21":"White Graduates",
                                            "Unnamed: 22":"White Grad Rate",
                                            "Paid Meals":"Paid Meals Cohort Count",
                                            "Unnamed: 24":"Paid Meals Graduates", 
                                            "Unnamed: 25":"Paid Meals Grad Rate",
                                            "Free/Reduced Price Meals":"Free/Reduced Meals Cohort Count",
                                            "Unnamed: 27":"Free/Reduced Meals Graduates",
                                            "Unnamed: 28":"Free/Reduced Meals Grad Rate",
                                            "General Education":"General Ed Cohort Count",
                                            "Unnamed: 30":"General Ed Graduates",
                                            "Unnamed: 31":"General Ed Grad Rate",
                                            "Special Education":"Special Ed Cohort Count",
                                            "Unnamed: 33":"Special Ed Graduates",
                                            "Unnamed: 34":"Special Ed Grad Rate",
                                            "Non-English Language Learner":"Non-English Language Learner Cohort Count", 
                                            "Unnamed: 36":"Non-English Language Learner Graduates",
                                            "Unnamed: 37":"Non-English Language Learner Grad Rate",
                                            "English Language Learner":"English Language Learner Cohort Count",
                                            "Unnamed: 39":"English Language Learner Graduates",
                                            "Unnamed: 40":"English Language Learner Grad Rate",
                                            "Female":"Female Cohort Count",
                                            "Unnamed: 42":"Female Graduates",
                                            "Unnamed: 43":"Female Grad Rate",
                                            "Male":"Male Cohort Count",
                                            "Unnamed: 45":"Male Graduates", 
                                            "Unnamed: 46":"Male Grad Rate",
                                            "Total":"Total Cohort Count", 
                                            "Unnamed: 48":"Total Graduates", 
                                            "Unnamed: 49":"Total Grad Rate"})
                                        
#renamed2017.head()

# %%
# drop the first row of data that csv file used as second column id row
clean_demo2017 = renamed2017.drop([0])
clean_demo2017.head()
# Out:
#   Corp ID                    Corporation Name Native American Cohort Count  \
# 1    0015     Adams Central Community Schools                          ***
# 2    0025       North Adams Community Schools                          ***
# 3    0035                 South Adams Schools                          ***
# 4    0125  M S D Southwest Allen County Schls                          NaN
# 5    0225      Northwest Allen County Schools                          ***
#
#   Native American Graduates Native American Grad Rate Asian Cohort Count  \
# 1                       ***                       ***                NaN
# 2                       ***                       ***                ***
# 3                       ***                       ***                ***
# 4                       NaN                       NaN                 15
# 5                       ***                       ***                 13
#
# ...

# %%
school_demo2018.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', '2018 State Graduation Rate Data',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49'],
#       dtype='object')

# %%
# rename columns for df use in pandas
renamed2018 = school_demo2018.rename(columns={"Unnamed: 0":"Corp ID", 
                                            "Unnamed: 1":"Corporation Name",
                                            "2018 State Graduation Rate Data":"Native American Cohort Count",
                                            "Unnamed: 3":"Native American Graduates",
                                            "Unnamed: 4":"Native American Grad Rate",
                                            "Unnamed: 5":"Asian Cohort Count",
                                            "Unnamed: 6":"Asian Graduates",
                                            "Unnamed: 7":"Asian Grad Rate",
                                            "Unnamed: 8":"Black Cohort Count",
                                            "Unnamed: 9":"Black Graduates",
                                            "Unnamed: 10":"Black Grad Rate",
                                            "Unnamed: 11":"Hispanic Cohort Count",
                                            "Unnamed: 12":"Hispanic Graduates",
                                            "Unnamed: 13":"Hispanic Grad Rate",
                                            "Unnamed: 14":"Multiracial Cohort Count",
                                            "Unnamed: 15":"Multiracial Graduates",
                                            "Unnamed: 16":"Multiracial Grad Rate",
                                            "Unnamed: 17":"Native Pacific Islander Cohort Count",
                                            "Unnamed: 18":"Native Pacific Islander Graduates",
                                            "Unnamed: 19":"Native Pacific Islander Grad Rate",
                                            "Unnamed: 20":"White Cohort Count", 
                                            "Unnamed: 21":"White Graduates",
                                            "Unnamed: 22":"White Grad Rate",
                                            "Unnamed: 23":"Paid Meals Cohort Count",
                                            "Unnamed: 24":"Paid Meals Graduates", 
                                            "Unnamed: 25":"Paid Meals Grad Rate",
                                            "Unnamed: 26":"Free/Reduced Meals Cohort Count",
                                            "Unnamed: 27":"Free/Reduced Meals Graduates",
                                            "Unnamed: 28":"Free/Reduced Meals Grad Rate",
                                            "Unnamed: 29":"General Ed Cohort Count",
                                            "Unnamed: 30":"General Ed Graduates",
                                            "Unnamed: 31":"General Ed Grad Rate",
                                            "Unnamed: 32":"Special Ed Cohort Count",
                                            "Unnamed: 33":"Special Ed Graduates",
                                            "Unnamed: 34":"Special Ed Grad Rate",
                                            "Unnamed: 35":"Non-English Language Learner Cohort Count", 
                                            "Unnamed: 36":"Non-English Language Learner Graduates",
                                            "Unnamed: 37":"Non-English Language Learner Grad Rate",
                                            "Unnamed: 38":"English Language Learner Cohort Count",
                                            "Unnamed: 39":"English Language Learner Graduates",
                                            "Unnamed: 40":"English Language Learner Grad Rate",
                                            "Unnamed: 41":"Female Cohort Count",
                                            "Unnamed: 42":"Female Graduates",
                                            "Unnamed: 43":"Female Grad Rate",
                                            "Unnamed: 44":"Male Cohort Count",
                                            "Unnamed: 45":"Male Graduates", 
                                            "Unnamed: 46":"Male Grad Rate",
                                            "Unnamed: 47":"Total Cohort Count", 
                                            "Unnamed: 48":"Total Graduates", 
                                            "Unnamed: 49":"Total Grad Rate"})
#renamed2018.head()

# %%
clean_demo2018 = renamed2018.drop([0,1])
clean_demo2018.head()
# Out:
#   Corp ID                    Corporation Name Native American Cohort Count  \
# 2    0015     Adams Central Community Schools                          NaN
# 3    0025       North Adams Community Schools                          ***
# 4    0035                 South Adams Schools                          NaN
# 5    0125  M S D Southwest Allen County Schls                          ***
# 6    0225      Northwest Allen County Schools                          ***
#
#   Native American Graduates Native American Grad Rate Asian Cohort Count  \
# 2                       NaN                       NaN                NaN
# 3                       ***                       ***                ***
# 4                       NaN                       NaN                NaN
# 5                       ***                       ***                 24
# 6                       ***                       ***                 16
#
# ...

# %%
school_demo2019.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', '2019 State Graduation Rate Data',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49'],
#       dtype='object')

# %%
# rename columns for df use in pandas
renamed2019 = school_demo2019.rename(columns={"Unnamed: 0":"Corp ID", 
                                            "Unnamed: 1":"Corporation Name",
                                            "2018 State Graduation Rate Data":"Native American Cohort Count",
                                            "Unnamed: 3":"Native American Graduates",
                                            "Unnamed: 4":"Native American Grad Rate",
                                            "Unnamed: 5":"Asian Cohort Count",
                                            "Unnamed: 6":"Asian Graduates",
                                            "Unnamed: 7":"Asian Grad Rate",
                                            "Unnamed: 8":"Black Cohort Count",
                                            "Unnamed: 9":"Black Graduates",
                                            "Unnamed: 10":"Black Grad Rate",
                                            "Unnamed: 11":"Hispanic Cohort Count",
                                            "Unnamed: 12":"Hispanic Graduates",
                                            "Unnamed: 13":"Hispanic Grad Rate",
                                            "Unnamed: 14":"Multiracial Cohort Count",
                                            "Unnamed: 15":"Multiracial Graduates",
                                            "Unnamed: 16":"Multiracial Grad Rate",
                                            "Unnamed: 17":"Native Pacific Islander Cohort Count",
                                            "Unnamed: 18":"Native Pacific Islander Graduates",
                                            "Unnamed: 19":"Native Pacific Islander Grad Rate",
                                            "Unnamed: 20":"White Cohort Count", 
                                            "Unnamed: 21":"White Graduates",
                                            "Unnamed: 22":"White Grad Rate",
                                            "Unnamed: 23":"Paid Meals Cohort Count",
                                            "Unnamed: 24":"Paid Meals Graduates", 
                                            "Unnamed: 25":"Paid Meals Grad Rate",
                                            "Unnamed: 26":"Free/Reduced Meals Cohort Count",
                                            "Unnamed: 27":"Free/Reduced Meals Graduates",
                                            "Unnamed: 28":"Free/Reduced Meals Grad Rate",
                                            "Unnamed: 29":"General Ed Cohort Count",
                                            "Unnamed: 30":"General Ed Graduates",
                                            "Unnamed: 31":"General Ed Grad Rate",
                                            "Unnamed: 32":"Special Ed Cohort Count",
                                            "Unnamed: 33":"Special Ed Graduates",
                                            "Unnamed: 34":"Special Ed Grad Rate",
                                            "Unnamed: 35":"Non-English Language Learner Cohort Count", 
                                            "Unnamed: 36":"Non-English Language Learner Graduates",
                                            "Unnamed: 37":"Non-English Language Learner Grad Rate",
                                            "Unnamed: 38":"English Language Learner Cohort Count",
                                            "Unnamed: 39":"English Language Learner Graduates",
                                            "Unnamed: 40":"English Language Learner Grad Rate",
                                            "Unnamed: 41":"Female Cohort Count",
                                            "Unnamed: 42":"Female Graduates",
                                            "Unnamed: 43":"Female Grad Rate",
                                            "Unnamed: 44":"Male Cohort Count",
                                            "Unnamed: 45":"Male Graduates", 
                                            "Unnamed: 46":"Male Grad Rate",
                                            "Unnamed: 47":"Total Cohort Count", 
                                            "Unnamed: 48":"Total Graduates", 
                                            "Unnamed: 49":"Total Grad Rate"})
#renamed2019.head()

# %%
clean_demo2019 = renamed2019.drop([0,1])
clean_demo2019.head()
# Out:
#   Corp ID                    Corporation Name 2019 State Graduation Rate Data  \
# 2    0015     Adams Central Community Schools                             NaN
# 3    0025       North Adams Community Schools                             NaN
# 4    0035                 South Adams Schools                             NaN
# 5    0125  M S D Southwest Allen County Schls                             ***
# 6    0225      Northwest Allen County Schools                             ***
#
#   Native American Graduates Native American Grad Rate Asian Cohort Count  \
# 2                       NaN                       NaN                NaN
# 3                       NaN                       NaN                ***
# 4                       NaN                       NaN                ***
# 5                       ***                       ***                 36
# 6                       ***                       ***                 21
#
# ...

# %%
clean_demo2019.to_csv("Resources/cleanschooldemographics2019.csv", index=False, header=True)

# %%
clean_demo2015.to_csv("Resources/cleanschooldemographics2015.csv", index=False, header=True)
clean_demo2016.to_csv("Resources/cleanschooldemographics2016.csv", index=False, header=True)
clean_demo2017.to_csv("Resources/cleanschooldemographics2017.csv", index=False, header=True)
clean_demo2018.to_csv("Resources/cleanschooldemographics2018.csv", index=False, header=True)

# %%
##

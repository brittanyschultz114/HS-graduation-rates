# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress

# %%
poverty_rate_df = pd.read_csv("Resources/combined_poverty_rate_revised.csv")
grad_rate_15_df = pd.read_csv("Resources/2015_grad_rates_revised.csv")
grad_rate_16_df = pd.read_csv("Resources/2016_grad_rates_revised.csv")
grad_rate_17_df = pd.read_csv("Resources/2017_grad_rates_revised.csv")
grad_rate_18_df = pd.read_csv("Resources/2018_grad_rates_revised.csv")
grad_rate_19_df = pd.read_csv("Resources/2019_grad_rates_revised.csv")
grad_rate_15_df.head()
# Out:
#    Corp Id                         CORPORATION NAME  Cohort N  Grad N  \
# 0       15          Adams Central Community Schools        95      90
# 1     5265  Alexandria Community School Corporation       112      98
# 2     5275    Anderson Community School Corporation       394     353
# 3     5470                  Argos Community Schools        46      34
# 4     2435   Attica Consolidated School Corporation        68      67
#
#   State Grad Rate  Non-Waiver Grad N State Non-Waiver Grad Rate
# 0          94.70%                 87                     91.60%
# 1          87.50%                 97                     86.60%
# 2          89.60%                277                     70.30%
# 3          73.90%                 34                     73.90%
# 4          98.50%                 64                     94.10%

# %%
# 2015 poverty rate vs 2015 graduation rate
poverty_15 = poverty_rate_df["2015 Poverty Rate"]
grad_15 = grad_rate_15_df["State Grad Rate"].str.replace('%','').astype(np.float64)
# line regression for 2015 pov rate and grad rate.
(slope, intercept, rvalue, pvalue, stderr) = linregress(grad_15,poverty_15)
regress_values = grad_15 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# Plot poverty rate vs. graduation rate.
plt.scatter(grad_15,poverty_15,marker="o", facecolors="green", edgecolors="black")
plt.plot(grad_15,regress_values,"r-")
plt.annotate(line_eq,(60,10),fontsize=15,color="red")
plt.title("2015 Poverty Rate vs. Graduation Rate")
plt.xlabel("Graduation Rate")
plt.ylabel("Poverty Rate")
plt.show()
print(f"The correlation coefficient between poverty rate and graduation rate is{round(st.pearsonr(grad_15,poverty_15)[0],2)}")
# Out:
# The correlation coefficient between poverty rate and graduation rate is-0.42

# %%
# 2015 poverty rate vs 2015 graduation rate
poverty_16 = poverty_rate_df["2016 Poverty Rate"]
grad_16 = grad_rate_16_df["State Grad Rate"].str.replace('%','').astype(np.float64)
# line regression for 2015 pov rate and grad rate.
(slope, intercept, rvalue, pvalue, stderr) = linregress(grad_16,poverty_16)
regress_values = grad_16 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# Plot poverty rate vs. graduation rate.
plt.scatter(grad_16,poverty_16,marker="o", facecolors="green", edgecolors="black")
plt.plot(grad_16,regress_values,"r-")
plt.annotate(line_eq,(60,10),fontsize=15,color="red")
plt.title("2016 Poverty Rate vs. Graduation Rate")
plt.xlabel("Graduation Rate")
plt.ylabel("Poverty Rate")
plt.show()
print(f"The correlation coefficient between poverty rate and graduation rate is{round(st.pearsonr(grad_16,poverty_16)[0],2)}")
# Out:
# The correlation coefficient between poverty rate and graduation rate is-0.4

# %%
# 2015 poverty rate vs 2015 graduation rate
poverty_17 = poverty_rate_df["2017 Poverty Rate"]
grad_17 = grad_rate_17_df["State Grad Rate"].str.replace('%','').astype(np.float64)
# line regression for 2015 pov rate and grad rate.
(slope, intercept, rvalue, pvalue, stderr) = linregress(grad_17,poverty_17)
regress_values = grad_17 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# Plot poverty rate vs. graduation rate.
plt.scatter(grad_17,poverty_17,marker="o", facecolors="green", edgecolors="black")
plt.plot(grad_17,regress_values,"r-")
plt.annotate(line_eq,(60,10),fontsize=15,color="red")
plt.title("2017 Poverty Rate vs. Graduation Rate")
plt.xlabel("Graduation Rate")
plt.ylabel("Poverty Rate")
plt.show()
print(f"The correlation coefficient between poverty rate and graduation rate is{round(st.pearsonr(grad_17,poverty_17)[0],2)}")
# Out:
# The correlation coefficient between poverty rate and graduation rate is-0.37

# %%
# 2018 poverty rate vs 2018 graduation rate
poverty_18 = poverty_rate_df["2018 Poverty Rate"]
grad_18 = grad_rate_18_df["State Grad Rate"].str.replace('%','').astype(np.float64)
# line regression for 2018 pov rate and grad rate.
(slope, intercept, rvalue, pvalue, stderr) = linregress(grad_18,poverty_18)
regress_values = grad_18 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# Plot poverty rate vs. graduation rate.
plt.scatter(grad_18,poverty_18,marker="o", facecolors="green", edgecolors="black")
plt.plot(grad_18,regress_values,"r-")
plt.annotate(line_eq,(60,10),fontsize=15,color="red")
plt.title("2018 Poverty Rate vs. Graduation Rate")
plt.xlabel("Graduation Rate")
plt.ylabel("Poverty Rate")
plt.show()
print(f"The correlation coefficient between poverty rate and graduation rate is{round(st.pearsonr(grad_18,poverty_18)[0],2)}")
# Out:
# The correlation coefficient between poverty rate and graduation rate is-0.44

# %%
# 2015 poverty rate vs 2015 graduation rate
poverty_19 = poverty_rate_df["2019 Poverty Rate"]
grad_19 = grad_rate_19_df["State Grad Rate"].str.replace('%','').astype(np.float64)
# line regression for 2015 pov rate and grad rate.
(slope, intercept, rvalue, pvalue, stderr) = linregress(grad_19,poverty_19)
regress_values = grad_19 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# Plot poverty rate vs. graduation rate.
plt.scatter(grad_19,poverty_19,marker="o", facecolors="green", edgecolors="black")
plt.plot(grad_19,regress_values,"r-")
plt.annotate(line_eq,(60,10),fontsize=15,color="red")
plt.title("2019 Poverty Rate vs. Graduation Rate")
plt.xlabel("Graduation Rate")
plt.ylabel("Poverty Rate")
plt.show()
print(f"The correlation coefficient between poverty rate and graduation rate is{round(st.pearsonr(grad_19,poverty_19)[0],2)}")
print(f"The r-squared is: {rvalue**2}")
# Out:
# The correlation coefficient between poverty rate and graduation rate is-0.44
# The r-squared is: 0.1963555758541084

# %%
plt.boxplot(grad_19)
plt.show()

# %%
plt.boxplot(poverty_19)
plt.show()

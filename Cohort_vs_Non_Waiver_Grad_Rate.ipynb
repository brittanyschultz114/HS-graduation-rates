# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress

# %%
grad_rate_15_df = pd.read_csv("Resources/2015_grad_rates_revised.csv")
grad_rate_16_df = pd.read_csv("Resources/2016_grad_rates_revised.csv")
grad_rate_17_df = pd.read_csv("Resources/2017_grad_rates_revised.csv")
grad_rate_18_df = pd.read_csv("Resources/2018_grad_rates_revised.csv")
grad_rate_19_df = pd.read_csv("Resources/2019_grad_rates_revised.csv")
grad_rate_15_df.head()
# Out:
#    Corp Id                         CORPORATION NAME  Cohort N  Grad N  \
# 0       15          Adams Central Community Schools        95      90
# 1     5265  Alexandria Community School Corporation       112      98
# 2     5275    Anderson Community School Corporation       394     353
# 3     5470                  Argos Community Schools        46      34
# 4     2435   Attica Consolidated School Corporation        68      67
#
#   State Grad Rate  Non-Waiver Grad N State Non-Waiver Grad Rate
# 0          94.70%                 87                     91.60%
# 1          87.50%                 97                     86.60%
# 2          89.60%                277                     70.30%
# 3          73.90%                 34                     73.90%
# 4          98.50%                 64                     94.10%

# %%
grad_rate_15 = grad_rate_15_df['State Non-Waiver Grad Rate'].str.replace('%','').astype(np.float64)
cohort_15 = grad_rate_15_df['Cohort N']
plt.figure(figsize=(8,6))
# line regression for 2015 pov rate and grad rate.
(slope, intercept, rvalue, pvalue, stderr) = linregress(grad_rate_15,cohort_15)
regress_values = grad_rate_15 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(grad_rate_15, cohort_15, color='teal', edgecolors="black")
plt.plot(grad_rate_15,regress_values,"r-")
plt.annotate(line_eq,(55,10),fontsize=15,color="red")

plt.title("2015 Non-Waiver Grad Rate vs. Cohort Size")
plt.xlabel("Graduation Rate")
plt.ylabel("Cohort Size")
plt.grid(alpha=.5)
plt.show

cc_cohort_2015 = round(st.pearsonr(grad_rate_15,cohort_15)[0],2)
print(f"The correlation coefficient between non-waiver graduation rate and cohort size is {cc_cohort_2015}")
# Out:
# The correlation coefficient between non-waiver graduation rate and cohort size is -0.16

# %%
grad_rate_16 = grad_rate_16_df['State Non-Waiver Grad Rate'].str.replace('%','').astype(np.float64)
cohort_16 = grad_rate_16_df['Cohort N']
plt.figure(figsize=(8,6))
# line regression for 2015 pov rate and grad rate.
(slope, intercept, rvalue, pvalue, stderr) = linregress(grad_rate_16,cohort_16)
regress_values = grad_rate_16 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(grad_rate_16, cohort_16, color='teal', edgecolors="black")
plt.plot(grad_rate_16,regress_values,"r-")
plt.annotate(line_eq,(70,500),fontsize=15,color="red")

plt.title("2016 Non-Waiver Grad Rate vs. Cohort Size")
plt.xlabel("Graduation Rate")
plt.ylabel("Cohort Size")
plt.grid(alpha=.5)
plt.show

cc_cohort_2016 = round(st.pearsonr(grad_rate_16,cohort_16)[0],2)
print(f"The correlation coefficient between non-waiver graduation rate and cohort size is {cc_cohort_2016}")
# Out:
# The correlation coefficient between non-waiver graduation rate and cohort size is -0.16

# %%
grad_rate_17 = grad_rate_17_df['State Non-Waiver Grad Rate'].str.replace('%','').astype(np.float64)
cohort_17 = grad_rate_17_df['Cohort N']
plt.figure(figsize=(8,6))
# line regression for 2015 pov rate and grad rate.
(slope, intercept, rvalue, pvalue, stderr) = linregress(grad_rate_17,cohort_17)
regress_values = grad_rate_17 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(grad_rate_17, cohort_17, color='teal', edgecolors="black")
plt.plot(grad_rate_17,regress_values,"r-")
plt.annotate(line_eq,(50,500),fontsize=15,color="red")

plt.title("2017 Non-Waiver Grad Rate vs. Cohort Size")
plt.xlabel("Graduation Rate")
plt.ylabel("Cohort Size")
plt.grid(alpha=.5)
plt.show

cc_cohort_2017 = round(st.pearsonr(grad_rate_17,cohort_17)[0],2)
print(f"The correlation coefficient between non-waiver graduation rate and cohort size is {cc_cohort_2017}")
# Out:
# The correlation coefficient between non-waiver graduation rate and cohort size is -0.17

# %%
grad_rate_18 = grad_rate_18_df['State Non-Waiver Grad Rate'].str.replace('%','').astype(np.float64)
cohort_18 = grad_rate_18_df['Cohort N']
plt.figure(figsize=(8,6))
# line regression for 2018 pov rate and grad rate.
(slope, intercept, rvalue, pvalue, stderr) = linregress(grad_rate_18,cohort_18)
regress_values = grad_rate_18 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(grad_rate_18, cohort_18, color='teal', edgecolors="black")
plt.plot(grad_rate_18,regress_values,"r-")
plt.annotate(line_eq,(70,500),fontsize=15,color="red")

plt.title("2018 Non-Waiver Grad Rate vs. Cohort Size")
plt.xlabel("Graduation Rate")
plt.ylabel("Cohort Size")
plt.grid(alpha=.5)
plt.show

cc_cohort_2018 = round(st.pearsonr(grad_rate_18,cohort_18)[0],2)
print(f"The correlation coefficient between non-waiver graduation rate and cohort size is {cc_cohort_2018}")
# Out:
# The correlation coefficient between non-waiver graduation rate and cohort size is -0.08

# %%
grad_rate_19 = grad_rate_19_df['State Non-Waiver Grad Rate'].str.replace('%','').astype(np.float64)
cohort_19 = grad_rate_19_df['Cohort N']
plt.figure(figsize=(8,6))
# line regression for 2015 pov rate and grad rate.
(slope, intercept, rvalue, pvalue, stderr) = linregress(grad_rate_19,cohort_19)
regress_values = grad_rate_19 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(grad_rate_19, cohort_19, color='teal', edgecolors="black")
plt.plot(grad_rate_19,regress_values,"r-")
plt.annotate(line_eq,(70,500),fontsize=15,color="red")

plt.title("2019 Non-Waiver Grad Rate vs. Cohort Size")
plt.xlabel("Graduation Rate")
plt.ylabel("Cohort Size")
plt.grid(alpha=.5)
plt.show

cc_cohort_2019 = round(st.pearsonr(grad_rate_19,cohort_19)[0],2)
print(f"The correlation coefficient between non-waiver graduation rate and cohort size is {cc_cohort_2019}")
# Out:
# The correlation coefficient between non-waiver graduation rate and cohort size is -0.08
